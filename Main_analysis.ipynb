# %% [markdown]
# # Music Recognition(SHAZAM) with Concrete ML

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import librosa
import os
from numpy.linalg import norm
from scipy.ndimage import maximum_filter
from scipy.ndimage import generate_binary_structure, binary_erosion
from concrete import fhe
from sklearn.linear_model import LogisticRegression
from concrete.ml.sklearn import DecisionTreeClassifier as ConcreteDTC
from concrete.ml.sklearn import LogisticRegression as ConcreteLR
from sklearn.model_selection import train_test_split
import time
import pandas as pd

# %% [markdown]
# ## CONSTANTS

# %%
MUSIC_DB_PATH = '../dataset_download/dataset2/fma_small'
TEST_SAMPLE_PATH = '../dataset_download/test_samples'
SAMPLE_RATE = 22050
MFCC_SAMPLES_PER_SEC = 2
NUM_SONGS = 400

# %% [markdown]
# ## Necessary functions for model

# %% [markdown]
# ### Compute features function.
# This function returns a matrix of features. The ith entry in `feats` is the sum of mfcc coefficients in a 500ms window, the entire song is divided into 500ms chunks.

# %%
def compute_features(y):
    feats = []
    win_sz = SAMPLE_RATE//MFCC_SAMPLES_PER_SEC
    for i in range(len(y)//win_sz):
        y_chunk = y[win_sz*i:win_sz*(i+1)]
        mfcc_f = np.sum(librosa.feature.mfcc(y=y_chunk, sr=SAMPLE_RATE), axis=1)
        feats.append(mfcc_f)
    return feats

# %% [markdown]
# ### Add features function.
# This function retrieves features for a specified song and appends it to a feature_db array along with its id.

# %%
feature_db = []
def add_features(y, id):
    feats = compute_features(y)
    for feat in feats:
        feature_db.append((feat, id))

# %% [markdown]
# Load 3 minute samples from each song from the specified directory and build the feature database.

# %%
idx = []

for dirpath, dnames, fnames in os.walk(MUSIC_DB_PATH):
    if len(idx) >= NUM_SONGS:
        break
    for f in fnames:
        try:
            song_name = f
            song_path = os.path.join(dirpath, f)
            y, sr = librosa.load(song_path, sr = SAMPLE_RATE, duration = 180)
            if song_name not in idx:
                idx.append(song_name)
                print(f"id: {idx.index(song_name)}, song_name: {song_name}")
            add_features(y, idx.index(song_name))
            if len(idx) >= NUM_SONGS:
                break
        except:
            pass
print(f"Total number of features to train on: {len(feature_db)}")
# Out:
# id: 0, song_name: 135054.mp3
# id: 1, song_name: 135336.mp3
# id: 2, song_name: 135337.mp3
# id: 3, song_name: 135043.mp3
# id: 4, song_name: 135091.mp3
# id: 5, song_name: 135092.mp3
# id: 6, song_name: 135044.mp3
# id: 7, song_name: 135989.mp3
# id: 8, song_name: 135221.mp3
# id: 9, song_name: 135369.mp3
# id: 10, song_name: 135341.mp3
# id: 11, song_name: 135340.mp3
# id: 12, song_name: 135368.mp3
# id: 13, song_name: 135220.mp3
# id: 14, song_name: 135222.mp3
# id: 15, song_name: 135342.mp3
# id: 16, song_name: 135223.mp3
# id: 17, song_name: 135227.mp3
# id: 18, song_name: 135226.mp3
# id: 19, song_name: 135224.mp3
# id: 20, song_name: 135219.mp3
# id: 21, song_name: 135225.mp3
# id: 22, song_name: 135228.mp3
# id: 23, song_name: 135374.mp3
# id: 24, song_name: 135375.mp3
# id: 25, song_name: 135229.mp3
# id: 26, song_name: 135363.mp3
# id: 27, song_name: 135028.mp3
# id: 28, song_name: 135010.mp3
# id: 29, song_name: 135986.mp3
# id: 30, song_name: 135372.mp3
# id: 31, song_name: 135373.mp3
# id: 32, song_name: 135039.mp3
# id: 33, song_name: 135365.mp3
# id: 34, song_name: 135371.mp3
# id: 35, song_name: 135370.mp3
# id: 36, song_name: 135364.mp3
# id: 37, song_name: 135990.mp3
# id: 38, song_name: 135089.mp3
# id: 39, song_name: 135339.mp3
# id: 40, song_name: 135338.mp3
# id: 41, song_name: 132117.mp3
# id: 42, song_name: 132675.mp3
# id: 43, song_name: 132310.mp3
# id: 44, song_name: 132272.mp3
# id: 45, song_name: 132448.mp3
# id: 46, song_name: 132138.mp3
# id: 47, song_name: 132677.mp3
# id: 48, song_name: 132139.mp3
# id: 49, song_name: 132449.mp3
# id: 50, song_name: 132566.mp3
# id: 51, song_name: 132567.mp3
# id: 52, song_name: 132773.mp3
# id: 53, song_name: 132954.mp3
# id: 54, song_name: 132789.mp3
# id: 55, song_name: 132171.mp3
# id: 56, song_name: 132561.mp3
# id: 57, song_name: 132788.mp3
# id: 58, song_name: 132775.mp3
# id: 59, song_name: 132589.mp3
# id: 60, song_name: 132774.mp3
# id: 61, song_name: 132779.mp3
# id: 62, song_name: 132786.mp3
# id: 63, song_name: 132792.mp3
# id: 64, song_name: 132962.mp3
# id: 65, song_name: 132142.mp3
# id: 66, song_name: 132963.mp3
# id: 67, song_name: 132793.mp3
# id: 68, song_name: 132787.mp3
# id: 69, song_name: 132778.mp3
# id: 70, song_name: 132791.mp3
# id: 71, song_name: 132961.mp3
# id: 72, song_name: 132424.mp3
# id: 73, song_name: 132140.mp3
# id: 74, song_name: 132141.mp3
# id: 75, song_name: 132784.mp3
# id: 76, song_name: 132790.mp3
# id: 77, song_name: 132019.mp3
# id: 78, song_name: 132964.mp3
# id: 79, song_name: 132794.mp3
# id: 80, song_name: 132434.mp3
# id: 81, song_name: 132420.mp3
# id: 82, song_name: 132568.mp3
# id: 83, song_name: 132781.mp3
# id: 84, song_name: 132795.mp3
# id: 85, song_name: 132965.mp3
# id: 86, song_name: 132436.mp3
# id: 87, song_name: 132040.mp3
# id: 88, song_name: 132134.mp3
# id: 89, song_name: 132914.mp3
# id: 90, song_name: 132041.mp3
# id: 91, song_name: 132453.mp3
# id: 92, song_name: 132679.mp3
# id: 93, song_name: 132678.mp3
# id: 94, song_name: 132122.mp3
# id: 95, song_name: 132042.mp3
# id: 96, song_name: 132456.mp3
# id: 97, song_name: 132045.mp3
# id: 98, song_name: 132455.mp3
# id: 99, song_name: 132118.mp3
# id: 100, song_name: 132454.mp3
# id: 101, song_name: 104276.mp3
# id: 102, song_name: 104277.mp3
# id: 103, song_name: 104063.mp3
# id: 104, song_name: 104062.mp3
# id: 105, song_name: 104066.mp3
# id: 106, song_name: 104067.mp3
# id: 107, song_name: 104065.mp3
# id: 108, song_name: 104064.mp3
# id: 109, song_name: 104010.mp3
# id: 110, song_name: 104625.mp3
# id: 111, song_name: 104779.mp3
# id: 112, song_name: 104009.mp3
# id: 113, song_name: 104357.mp3
# id: 114, song_name: 104356.mp3
# id: 372, song_name: 134052.mp3
# id: 373, song_name: 134790.mp3
# id: 374, song_name: 134948.mp3
# id: 375, song_name: 134586.mp3
# id: 376, song_name: 134949.mp3
# id: 377, song_name: 134791.mp3
# id: 378, song_name: 134034.mp3
# id: 379, song_name: 134801.mp3
# id: 380, song_name: 134793.mp3
# id: 381, song_name: 134962.mp3
# id: 382, song_name: 134792.mp3
# id: 383, song_name: 134631.mp3
# id: 384, song_name: 134796.mp3
# id: 385, song_name: 134594.mp3
# id: 386, song_name: 134580.mp3
# id: 387, song_name: 134797.mp3
# id: 388, song_name: 134385.mp3
# id: 389, song_name: 134959.mp3
# id: 390, song_name: 134795.mp3
# id: 391, song_name: 134794.mp3
# id: 392, song_name: 134384.mp3
# id: 393, song_name: 151404.mp3
# id: 394, song_name: 024367.mp3
# id: 395, song_name: 024429.mp3
# id: 396, song_name: 024428.mp3
# id: 397, song_name: 024366.mp3
# id: 398, song_name: 024364.mp3
# id: 399, song_name: 024370.mp3
# Total number of features to train on: 23770

# %%
features = np.array([fp[0] for fp in feature_db])
ids = np.array([fp[1] for fp in feature_db])
print("initial bincount of features with respect to class ids:",np.bincount(ids))
# Out:
# initial bincount of features with respect to class ids: [60 59 60 60 59 59 59 60 59 59 59 60 59 59 59 59 59 60 60 60 59 59 60 60
#  60 59 60 59 59 59 60 59 59 60 59 60 59 59 59 59 60 59 59 59 60 60 60 59
#  59 59 59 59 59 59 59 60 60 59 59 60 60 59 59 59 59 59 59 59 59 59 59 59
#  60 59 59 59 59 59 59 59 59 59 59 59 59 59 59 59 59 59 59 59 59 59 59 59
#  59 60 59 59 59 60 60 60 59 59 60 60 60 59 59 60 59 59 60 59 60 60 59 59
#  59 59 60 59 60 60 60 60 59 59 59 60 59 59 59 59 59 60 60 59 59 59 60 60
#  59 60 60 59 59 60 60 59 60 60 59 59 59 60 59 60 59 59 59 60 59 59 60 59
#  59 60 60 60 60 59 59 60 60 60 60 60 59 60 59 60 59 60 59 59 59 60 60 59
#  60 59 59 59 59 59 59 60 59 60 60 60 59 59 60 59 59 60 60 60 60 59 60 59
#  60 60 60 60 59 59 60 59 60 60 59 59 59 59 60 59 59 59 59 59 59 60 60 60
#  59 60 60 59 60 59 60 60 59 60 59 59 60 60 60 60 60 59 59 60 60 60 59 60
#  59 60 59 59 59 60 59 59 59 60 59 59 60 59 60 60 60 59 59 59 59 60 59 59
#  60 60 59 60 60 59 60 59 59 59 60 60 59 59 60 60 59 59 60 59 60 60 60 60
#  59 59 60 60 60 60 59 59 60 59 59 60 60 59 59 59 60 60 59 60 60 59 59 59
#  59 59 59 59 60 59 60 60 60 60 60 60 59 59 60 59 59 60 60 59 60 59 60 60
#  59 59 59 59 59 60 59 60 60 60 59 60 59 59 60 59 60 60 59 59 60 59 60 59
#  59 59 60 59 59 60 60 60 60 60 59 59 60 60 59 59]

# %% [markdown]
# ## Evaluation function
# - Model: the model to be evaluated
# - Model Config: Model config parameters such as name, n_bits, max_depth
# - truth_label: A dictionary which maps the test sample file name to corresponding true id
# - predict_in_fhe: If true the prediction is run in fhe mode instead of simulation

# %%
def evaluate(model, model_config, truth_label, samples_path, predict_in_fhe = False):
    evaluation = {**model_config}
    evaluation["Inference Time"] = 0
    evaluation["Accuracy"] = 0

    if predict_in_fhe:
        evaluation["Inference Time (FHE)"] = 0
        evaluation["Accuracy (FHE)"] = 0

    for dirpath, dnames, fnames in os.walk(samples_path):
        for f in fnames:
            if f not in truth_label:
                continue
            
            print(f"processing {f}")
            song_path = os.path.join(dirpath, f)
            y, sr = librosa.load(song_path, sr = SAMPLE_RATE, duration = 15)
            features = compute_features(y)

            start = time.time()
            preds = model.predict(features)
            end = time.time()

            evaluation["Inference Time"] += end-start

            class_prediction = np.argmax(np.bincount(preds))
            if np.bincount(preds)[class_prediction] < 5:
                class_prediction = -1 # Unknown Class
            
            
            
            evaluation["Accuracy"] += (class_prediction == truth_label[f])
    
            if predict_in_fhe:
                start = time.time()
                preds = model.predict(features, fhe="execute")
                end = time.time()

                evaluation["Inference Time (FHE)"] += end-start

                class_prediction = np.argmax(np.bincount(preds))
                if np.bincount(preds)[class_prediction] < 5:
                    class_prediction = -1 
                
                
                
                evaluation["Accuracy (FHE)"] += (class_prediction == truth_label[f])
    evaluation["Accuracy"] /= len(truth_label)
    evaluation["Inference Time"] /= len(truth_label)

    if predict_in_fhe:
        evaluation["Inference Time (FHE)"] /= len(truth_label)
        evaluation["Accuracy (FHE)"] /= len(truth_label)
    return evaluation

# %% [markdown]
# ## Models

# %%
concrete_configs = [ {'n_bits': 8}]
concrete_models = [ConcreteLR(**concrete_configs[0]) ]

# %%
for model in concrete_models:
    model.fit(features, ids)
    model.compile(features)

# %% [markdown]
# First we evaluate the models on a small hand curated recording sample set. This was created by playing the music on the phone and recording it through the laptops microphone.

# %%
#truth_label = {"sample1.mp3": idx.index("Alena Smirnova - Lyric song.mp3"),
#               "sample2.mp3": idx.index("Edoy - Topaz.mp3"),
#               "sample3_recorded.m4a": idx.index("Pierce Murphy - Devil In A Falling Sky.mp3")}
truth_label = {
               "133916.mp3": idx.index("133916.mp3"),
               "135054.mp3": idx.index("135054.mp3"),
               "024366.mp3": idx.index("024366.mp3"),
              }

print(truth_label)
# Out:
# {'133916.mp3': 247, '135054.mp3': 0, '024366.mp3': 397, '024366_recorded.m4a': 397}

# %%
evaluations = {}
model_names = [ "ConcreteLR"]
for i, model in enumerate(concrete_models):
    evaluations[model_names[i]] = evaluate(model, concrete_configs[i], truth_label, TEST_SAMPLE_PATH, predict_in_fhe=True)
# Out:
# sample 135054.mp3: prediction 0
# sample 135054.mp3: prediction 0
# sample 024366.mp3: prediction 397
# sample 024366.mp3: prediction 397
# sample 133916.mp3: prediction 247
# sample 133916.mp3: prediction 247
# sample 024366_recorded.m4a: prediction 293
# sample 024366_recorded.m4a: prediction 293

# %%
import pandas as pd
df = pd.DataFrame(evaluations)
df
# Out:
#                       ConcreteLR
# Accuracy                0.750000
# Accuracy (FHE)          0.750000
# Inference Time          0.008017
# Inference Time (FHE)    0.304193
# n_bits                  8.000000

# %%
truth_label_train = {}

for i, id in enumerate(idx):
    truth_label_train[id] = i

# %%
evaluations = {}
model_names = [ "ConcreteLR"]
for i, model in enumerate(concrete_models):
    evaluations[model_names[i]] = evaluate(model, concrete_configs[i], truth_label_train, MUSIC_DB_PATH, predict_in_fhe=True)
# Out:
# processing 135054.mp3
# processing 135336.mp3
# processing 135337.mp3
# processing 135043.mp3
# processing 135091.mp3
# processing 135092.mp3
# processing 135044.mp3
# processing 135989.mp3
# processing 135221.mp3
# processing 135369.mp3
# processing 135341.mp3
# processing 135340.mp3
# processing 135368.mp3
# processing 135220.mp3
# processing 135222.mp3
# processing 135342.mp3
# processing 135223.mp3
# processing 135227.mp3
# processing 135226.mp3
# processing 135224.mp3
# processing 135219.mp3
# processing 135225.mp3
# processing 135228.mp3
# processing 135374.mp3
# processing 135375.mp3
# processing 135229.mp3
# processing 135363.mp3
# processing 135028.mp3
# processing 135010.mp3
# processing 135986.mp3
# processing 135372.mp3
# processing 135373.mp3
# processing 135039.mp3
# processing 135365.mp3
# processing 135371.mp3
# processing 135370.mp3
# processing 135364.mp3
# processing 135990.mp3
# processing 135089.mp3
# processing 135339.mp3
# processing 135338.mp3
# processing 132117.mp3
# processing 132675.mp3
# processing 132310.mp3
# processing 132272.mp3
# processing 132448.mp3
# processing 132138.mp3
# processing 132677.mp3
# processing 132139.mp3
# processing 132449.mp3
# processing 132566.mp3
# processing 132567.mp3
# processing 132773.mp3
# processing 132954.mp3
# processing 132789.mp3
# processing 132171.mp3
# processing 132561.mp3
# processing 132788.mp3
# processing 132775.mp3
# processing 132589.mp3
# processing 132774.mp3
# processing 132779.mp3
# processing 132786.mp3
# processing 132792.mp3
# processing 132962.mp3
# processing 132142.mp3
# processing 132963.mp3
# processing 132793.mp3
# processing 132787.mp3
# processing 132778.mp3
# processing 132791.mp3
# processing 132961.mp3
# processing 132424.mp3
# processing 132140.mp3
# processing 132141.mp3
# processing 132784.mp3
# processing 132790.mp3
# processing 132019.mp3
# processing 132964.mp3
# processing 132794.mp3
# processing 132434.mp3
# processing 132420.mp3
# processing 132568.mp3
# processing 132781.mp3
# processing 132795.mp3
# processing 132965.mp3
# processing 132436.mp3
# processing 132040.mp3
# processing 132134.mp3
# processing 132914.mp3
# processing 132041.mp3
# processing 132453.mp3
# processing 132679.mp3
# processing 132678.mp3
# processing 132122.mp3
# processing 132042.mp3
# processing 132456.mp3
# processing 132045.mp3
# processing 132455.mp3
# processing 132118.mp3
# processing 132454.mp3
# processing 104276.mp3
# processing 104277.mp3
# processing 104063.mp3
# processing 104062.mp3
# processing 104066.mp3
# processing 104067.mp3
# processing 104065.mp3
# processing 104064.mp3
# processing 104010.mp3
# processing 104625.mp3
# processing 104779.mp3
# processing 104009.mp3
# processing 104357.mp3
# processing 104356.mp3
# processing 104008.mp3
# processing 104434.mp3
# processing 104780.mp3
# processing 104227.mp3
# processing 104068.mp3
# processing 104283.mp3
# processing 104724.mp3
# processing 104725.mp3
# processing 104282.mp3
# processing 104279.mp3
# processing 104668.mp3
# processing 104278.mp3
# processing 104086.mp3
# processing 104284.mp3
# processing 103519.mp3
# processing 103518.mp3
# processing 103523.mp3
# processing 103522.mp3
# processing 103520.mp3
# processing 103521.mp3
# processing 103800.mp3
# processing 103808.mp3
# processing 103600.mp3
# processing 150018.mp3
# processing 150268.mp3
# processing 150080.mp3
# processing 150078.mp3
# processing 150079.mp3
# processing 150287.mp3
# processing 150063.mp3
# processing 150062.mp3
# processing 150288.mp3
# processing 150267.mp3
# processing 150064.mp3
# processing 150266.mp3
# processing 150073.mp3
# processing 150265.mp3
# processing 150015.mp3
# processing 150017.mp3
# processing 102114.mp3
# processing 102112.mp3
# processing 102092.mp3
# processing 102195.mp3
# processing 105141.mp3
# processing 105196.mp3
# processing 105022.mp3
# processing 105142.mp3
# processing 105145.mp3
# processing 105408.mp3
# processing 105144.mp3
# processing 105916.mp3
# processing 105719.mp3
# processing 105718.mp3
# processing 105917.mp3
# processing 105685.mp3
# processing 105450.mp3
# processing 105915.mp3
# processing 105914.mp3
# processing 105451.mp3
# processing 105119.mp3
# processing 105722.mp3
# processing 105683.mp3
# processing 105720.mp3
# processing 105912.mp3
# processing 105443.mp3
# processing 105682.mp3
# processing 105670.mp3
# processing 105664.mp3
# processing 105671.mp3
# processing 105673.mp3
# processing 105920.mp3
# processing 105713.mp3
# processing 105712.mp3
# processing 105672.mp3
# processing 105662.mp3
# processing 105919.mp3
# processing 105716.mp3
# processing 105717.mp3
# processing 105918.mp3
# processing 105887.mp3
# processing 105715.mp3
# processing 105714.mp3
# processing 105890.mp3
# processing 105674.mp3
# processing 105411.mp3
# processing 105412.mp3
# processing 105413.mp3
# processing 105826.mp3
# processing 105827.mp3
# processing 105825.mp3
# processing 105414.mp3
# processing 105824.mp3
# processing 133431.mp3
# processing 133974.mp3
# processing 133579.mp3
# processing 133551.mp3
# processing 133545.mp3
# processing 133544.mp3
# processing 133975.mp3
# processing 133020.mp3
# processing 133632.mp3
# processing 133432.mp3
# processing 133803.mp3
# processing 133022.mp3
# processing 133977.mp3
# processing 133793.mp3
# processing 133546.mp3
# processing 133553.mp3
# processing 133976.mp3
# processing 133023.mp3
# processing 133802.mp3
# processing 133433.mp3
# processing 133437.mp3
# processing 133027.mp3
# processing 133972.mp3
# processing 133580.mp3
# processing 133973.mp3
# processing 133967.mp3
# processing 133026.mp3
# processing 133436.mp3
# processing 133434.mp3
# processing 133024.mp3
# processing 133781.mp3
# processing 133971.mp3
# processing 133970.mp3
# processing 133780.mp3
# processing 133019.mp3
# processing 133025.mp3
# processing 133838.mp3
# processing 133435.mp3
# processing 133446.mp3
# processing 133452.mp3
# processing 133916.mp3
# processing 133731.mp3
# processing 133453.mp3
# processing 133447.mp3
# processing 133479.mp3
# processing 133451.mp3
# processing 133445.mp3
# processing 133294.mp3
# processing 133444.mp3
# processing 133450.mp3
# processing 133332.mp3
# processing 133454.mp3
# processing 133440.mp3
# processing 133681.mp3
# processing 133535.mp3
# processing 133441.mp3
# processing 133333.mp3
# processing 133455.mp3
# processing 133443.mp3
# processing 133457.mp3
# processing 133537.mp3
# processing 133293.mp3
# processing 133456.mp3
# processing 133442.mp3
# processing 133275.mp3
# processing 133274.mp3
# processing 133102.mp3
# processing 133100.mp3
# processing 133538.mp3
# processing 133276.mp3
# processing 133459.mp3
# processing 133449.mp3
# processing 133273.mp3
# processing 133272.mp3
# processing 133448.mp3
# processing 133729.mp3
# processing 133438.mp3
# processing 133835.mp3
# processing 133028.mp3
# processing 133772.mp3
# processing 133969.mp3
# processing 133564.mp3
# processing 133571.mp3
# processing 133968.mp3
# processing 133798.mp3
# processing 133015.mp3
# processing 133029.mp3
# processing 133439.mp3
# processing 133639.mp3
# processing 133836.mp3
# processing 133942.mp3
# processing 133567.mp3
# processing 133573.mp3
# processing 133572.mp3
# processing 133943.mp3
# processing 133016.mp3
# processing 133770.mp3
# processing 133837.mp3
# processing 133638.mp3
# processing 133833.mp3
# processing 133562.mp3
# processing 133576.mp3
# processing 133563.mp3
# processing 133978.mp3
# processing 133788.mp3
# processing 133561.mp3
# processing 133560.mp3
# processing 133574.mp3
# processing 134389.mp3
# processing 134941.mp3
# processing 134940.mp3
# processing 134388.mp3
# processing 134981.mp3
# processing 134956.mp3
# processing 134942.mp3
# processing 134943.mp3
# processing 134823.mp3
# processing 134610.mp3
# processing 134827.mp3
# processing 134947.mp3
# processing 134952.mp3
# processing 134826.mp3
# processing 134359.mp3
# processing 134824.mp3
# processing 134950.mp3
# processing 134979.mp3
# processing 134951.mp3
# processing 134825.mp3
# processing 134077.mp3
# processing 134922.mp3
# processing 134936.mp3
# processing 134937.mp3
# processing 134923.mp3
# processing 134935.mp3
# processing 134510.mp3
# processing 134934.mp3
# processing 134449.mp3
# processing 134930.mp3
# processing 134918.mp3
# processing 134919.mp3
# processing 134931.mp3
# processing 134448.mp3
# processing 134933.mp3
# processing 134932.mp3
# processing 134073.mp3
# processing 134452.mp3
# processing 134446.mp3
# processing 134094.mp3
# processing 134447.mp3
# processing 134453.mp3
# processing 134445.mp3
# processing 134486.mp3
# processing 134928.mp3
# processing 134929.mp3
# processing 134054.mp3
# processing 134444.mp3
# processing 134454.mp3
# processing 134939.mp3
# processing 134509.mp3
# processing 134938.mp3
# processing 134643.mp3
# processing 134455.mp3
# processing 134443.mp3
# processing 134053.mp3
# processing 134084.mp3
# processing 134052.mp3
# processing 134790.mp3
# processing 134948.mp3
# processing 134586.mp3
# processing 134949.mp3
# processing 134791.mp3
# processing 134034.mp3
# processing 134801.mp3
# processing 134793.mp3
# processing 134962.mp3
# processing 134792.mp3
# processing 134631.mp3
# processing 134796.mp3
# processing 134594.mp3
# processing 134580.mp3
# processing 134797.mp3
# processing 134385.mp3
# processing 134959.mp3
# processing 134795.mp3
# processing 134794.mp3
# processing 134384.mp3
# processing 151404.mp3
# processing 024367.mp3
# processing 024429.mp3
# processing 024428.mp3
# processing 024366.mp3
# processing 024364.mp3
# processing 024370.mp3

# %%
import pandas as pd
df = pd.DataFrame(evaluations)
df
# Out:
#                       ConcreteLR
# Accuracy                0.972500
# Accuracy (FHE)          0.972500
# Inference Time          0.000585
# Inference Time (FHE)    0.320240
# n_bits                  8.000000

# %% [markdown]
# ## Comparision with SKlearn LR model

# %%
from sklearn.linear_model import LogisticRegression

sklearn_lr = LogisticRegression().fit(features, ids)

# %%
evaluations["sklearn_lr"] = evaluate(sklearn_lr, {}, truth_label_train, MUSIC_DB_PATH, predict_in_fhe=False)
# Out:
# processing 135054.mp3
# processing 135336.mp3
# processing 135337.mp3
# processing 135043.mp3
# processing 135091.mp3
# processing 135092.mp3
# processing 135044.mp3
# processing 135989.mp3
# processing 135221.mp3
# processing 135369.mp3
# processing 135341.mp3
# processing 135340.mp3
# processing 135368.mp3
# processing 135220.mp3
# processing 135222.mp3
# processing 135342.mp3
# processing 135223.mp3
# processing 135227.mp3
# processing 135226.mp3
# processing 135224.mp3
# processing 135219.mp3
# processing 135225.mp3
# processing 135228.mp3
# processing 135374.mp3
# processing 135375.mp3
# processing 135229.mp3
# processing 135363.mp3
# processing 135028.mp3
# processing 135010.mp3
# processing 135986.mp3
# processing 135372.mp3
# processing 135373.mp3
# processing 135039.mp3
# processing 135365.mp3
# processing 135371.mp3
# processing 135370.mp3
# processing 135364.mp3
# processing 135990.mp3
# processing 135089.mp3
# processing 135339.mp3
# processing 135338.mp3
# processing 132117.mp3
# processing 132675.mp3
# processing 132310.mp3
# processing 132272.mp3
# processing 132448.mp3
# processing 132138.mp3
# processing 132677.mp3
# processing 132139.mp3
# processing 132449.mp3
# processing 132566.mp3
# processing 132567.mp3
# processing 132773.mp3
# processing 132954.mp3
# processing 132789.mp3
# processing 132171.mp3
# processing 132561.mp3
# processing 132788.mp3
# processing 132775.mp3
# processing 132589.mp3
# processing 132774.mp3
# processing 132779.mp3
# processing 132786.mp3
# processing 132792.mp3
# processing 132962.mp3
# processing 132142.mp3
# processing 132963.mp3
# processing 132793.mp3
# processing 132787.mp3
# processing 132778.mp3
# processing 132791.mp3
# processing 132961.mp3
# processing 132424.mp3
# processing 132140.mp3
# processing 132141.mp3
# processing 132784.mp3
# processing 132790.mp3
# processing 132019.mp3
# processing 132964.mp3
# processing 132794.mp3
# processing 132434.mp3
# processing 132420.mp3
# processing 132568.mp3
# processing 132781.mp3
# processing 132795.mp3
# processing 132965.mp3
# processing 132436.mp3
# processing 132040.mp3
# processing 132134.mp3
# processing 132914.mp3
# processing 132041.mp3
# processing 132453.mp3
# processing 132679.mp3
# processing 132678.mp3
# processing 132122.mp3
# processing 132042.mp3
# processing 132456.mp3
# processing 132045.mp3
# processing 132455.mp3
# processing 132118.mp3
# processing 132454.mp3
# processing 104276.mp3
# processing 104277.mp3
# processing 104063.mp3
# processing 104062.mp3
# processing 104066.mp3
# processing 104067.mp3
# processing 104065.mp3
# processing 104064.mp3
# processing 104010.mp3
# processing 104625.mp3
# processing 104779.mp3
# processing 104009.mp3
# processing 104357.mp3
# processing 104356.mp3
# processing 104008.mp3
# processing 104434.mp3
# processing 104780.mp3
# processing 104227.mp3
# processing 104068.mp3
# processing 104283.mp3
# processing 104724.mp3
# processing 104725.mp3
# processing 104282.mp3
# processing 104279.mp3
# processing 104668.mp3
# processing 104278.mp3
# processing 104086.mp3
# processing 104284.mp3
# processing 103519.mp3
# processing 103518.mp3
# processing 103523.mp3
# processing 103522.mp3
# processing 103520.mp3
# processing 103521.mp3
# processing 103800.mp3
# processing 103808.mp3
# processing 103600.mp3
# processing 150018.mp3
# processing 150268.mp3
# processing 150080.mp3
# processing 150078.mp3
# processing 150079.mp3
# processing 150287.mp3
# processing 150063.mp3
# processing 150062.mp3
# processing 150288.mp3
# processing 150267.mp3
# processing 150064.mp3
# processing 150266.mp3
# processing 150073.mp3
# processing 150265.mp3
# processing 150015.mp3
# processing 150017.mp3
# processing 102114.mp3
# processing 102112.mp3
# processing 102092.mp3
# processing 102195.mp3
# processing 105141.mp3
# processing 105196.mp3
# processing 105022.mp3
# processing 105142.mp3
# processing 105145.mp3
# processing 105408.mp3
# processing 105144.mp3
# processing 105916.mp3
# processing 105719.mp3
# processing 105718.mp3
# processing 105917.mp3
# processing 105685.mp3
# processing 105450.mp3
# processing 105915.mp3
# processing 105914.mp3
# processing 105451.mp3
# processing 105119.mp3
# processing 105722.mp3
# processing 105683.mp3
# processing 105720.mp3
# processing 105912.mp3
# processing 105443.mp3
# processing 105682.mp3
# processing 105670.mp3
# processing 105664.mp3
# processing 105671.mp3
# processing 105673.mp3
# processing 105920.mp3
# processing 105713.mp3
# processing 105712.mp3
# processing 105672.mp3
# processing 105662.mp3
# processing 105919.mp3
# processing 105716.mp3
# processing 105717.mp3
# processing 105918.mp3
# processing 105887.mp3
# processing 105715.mp3
# processing 105714.mp3
# processing 105890.mp3
# processing 105674.mp3
# processing 105411.mp3
# processing 105412.mp3
# processing 105413.mp3
# processing 105826.mp3
# processing 105827.mp3
# processing 105825.mp3
# processing 105414.mp3
# processing 105824.mp3
# processing 133431.mp3
# processing 133974.mp3
# processing 133579.mp3
# processing 133551.mp3
# processing 133545.mp3
# processing 133544.mp3
# processing 133975.mp3
# processing 133020.mp3
# processing 133632.mp3
# processing 133432.mp3
# processing 133803.mp3
# processing 133022.mp3
# processing 133977.mp3
# processing 133793.mp3
# processing 133546.mp3
# processing 133553.mp3
# processing 133976.mp3
# processing 133023.mp3
# processing 133802.mp3
# processing 133433.mp3
# processing 133437.mp3
# processing 133027.mp3
# processing 133972.mp3
# processing 133580.mp3
# processing 133973.mp3
# processing 133967.mp3
# processing 133026.mp3
# processing 133436.mp3
# processing 133434.mp3
# processing 133024.mp3
# processing 133781.mp3
# processing 133971.mp3
# processing 133970.mp3
# processing 133780.mp3
# processing 133019.mp3
# processing 133025.mp3
# processing 133838.mp3
# processing 133435.mp3
# processing 133446.mp3
# processing 133452.mp3
# processing 133916.mp3
# processing 133731.mp3
# processing 133453.mp3
# processing 133447.mp3
# processing 133479.mp3
# processing 133451.mp3
# processing 133445.mp3
# processing 133294.mp3
# processing 133444.mp3
# processing 133450.mp3
# processing 133332.mp3
# processing 133454.mp3
# processing 133440.mp3
# processing 133681.mp3
# processing 133535.mp3
# processing 133441.mp3
# processing 133333.mp3
# processing 133455.mp3
# processing 133443.mp3
# processing 133457.mp3
# processing 133537.mp3
# processing 133293.mp3
# processing 133456.mp3
# processing 133442.mp3
# processing 133275.mp3
# processing 133274.mp3
# processing 133102.mp3
# processing 133100.mp3
# processing 133538.mp3
# processing 133276.mp3
# processing 133459.mp3
# processing 133449.mp3
# processing 133273.mp3
# processing 133272.mp3
# processing 133448.mp3
# processing 133729.mp3
# processing 133438.mp3
# processing 133835.mp3
# processing 133028.mp3
# processing 133772.mp3
# processing 133969.mp3
# processing 133564.mp3
# processing 133571.mp3
# processing 133968.mp3
# processing 133798.mp3
# processing 133015.mp3
# processing 133029.mp3
# processing 133439.mp3
# processing 133639.mp3
# processing 133836.mp3
# processing 133942.mp3
# processing 133567.mp3
# processing 133573.mp3
# processing 133572.mp3
# processing 133943.mp3
# processing 133016.mp3
# processing 133770.mp3
# processing 133837.mp3
# processing 133638.mp3
# processing 133833.mp3
# processing 133562.mp3
# processing 133576.mp3
# processing 133563.mp3
# processing 133978.mp3
# processing 133788.mp3
# processing 133561.mp3
# processing 133560.mp3
# processing 133574.mp3
# processing 134389.mp3
# processing 134941.mp3
# processing 134940.mp3
# processing 134388.mp3
# processing 134981.mp3
# processing 134956.mp3
# processing 134942.mp3
# processing 134943.mp3
# processing 134823.mp3
# processing 134610.mp3
# processing 134827.mp3
# processing 134947.mp3
# processing 134952.mp3
# processing 134826.mp3
# processing 134359.mp3
# processing 134824.mp3
# processing 134950.mp3
# processing 134979.mp3
# processing 134951.mp3
# processing 134825.mp3
# processing 134077.mp3
# processing 134922.mp3
# processing 134936.mp3
# processing 134937.mp3
# processing 134923.mp3
# processing 134935.mp3
# processing 134510.mp3
# processing 134934.mp3
# processing 134449.mp3
# processing 134930.mp3
# processing 134918.mp3
# processing 134919.mp3
# processing 134931.mp3
# processing 134448.mp3
# processing 134933.mp3
# processing 134932.mp3
# processing 134073.mp3
# processing 134452.mp3
# processing 134446.mp3
# processing 134094.mp3
# processing 134447.mp3
# processing 134453.mp3
# processing 134445.mp3
# processing 134486.mp3
# processing 134928.mp3
# processing 134929.mp3
# processing 134054.mp3
# processing 134444.mp3
# processing 134454.mp3
# processing 134939.mp3
# processing 134509.mp3
# processing 134938.mp3
# processing 134643.mp3
# processing 134455.mp3
# processing 134443.mp3
# processing 134053.mp3
# processing 134084.mp3
# processing 134052.mp3
# processing 134790.mp3
# processing 134948.mp3
# processing 134586.mp3
# processing 134949.mp3
# processing 134791.mp3
# processing 134034.mp3
# processing 134801.mp3
# processing 134793.mp3
# processing 134962.mp3
# processing 134792.mp3
# processing 134631.mp3
# processing 134796.mp3
# processing 134594.mp3
# processing 134580.mp3
# processing 134797.mp3
# processing 134385.mp3
# processing 134959.mp3
# processing 134795.mp3
# processing 134794.mp3
# processing 134384.mp3
# processing 151404.mp3
# processing 024367.mp3
# processing 024429.mp3
# processing 024428.mp3
# processing 024366.mp3
# processing 024364.mp3
# processing 024370.mp3

# %%
df = pd.DataFrame(evaluations)
df
# Out:
#                       ConcreteLR  sklearn_lr
# n_bits                  8.000000         NaN
# Inference Time          0.000585    0.000214
# Accuracy                0.972500    0.977500
# Inference Time (FHE)    0.320240         NaN
# Accuracy (FHE)          0.972500         NaN
